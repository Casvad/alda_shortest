# %%
pip install matplotlib
# Out:
# ...
#   Using cached contourpy-1.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.1/159.1 kB 900.2 kB/s eta 0:00:00a 0:00:01
# ...
#   Using cached kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# ...
#   Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (114 kB)
# ...
#   Using cached pillow-10.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.7 kB)
# ...
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 17.3 MB/s eta 0:00:00a 0:00:01
# Using cached contourpy-1.2.0-cp311-cp311-macosx_11_0_arm64.whl (243 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 14.5 MB/s eta 0:00:0000:0100:01
# Using cached kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl (66 kB)
# ...

# %%
with open("out.txt", "r") as file:
    data = file.read()
    data = data.replace("[", "").replace("]", "").split("\n")
    data.pop()
data = [list(map(int, line.strip("").split(", "))) for line in data]

# %%
data
# Out:
# [[1000000, 2, 7216, 1],
#  [11000000, 1, 172696, 1],
#  [21000000, 19, 228711, 18],
#  [31000000, 14, 401433, 27],
#  [41000000, 14, 853046, 24],
#  [51000000, 32, 958574, 23],
#  [61000000, 37, 1219783, 25],
#  [71000000, 20, 1509816, 112],
#  [81000000, 32, 2636287, 101],
#  [91000000, 50, 5563026, 119],
#  [100, 2467, 324, 4097],
#  [200, 20211, 2364, 32090],
#  [300, 71017, 10194, 105825],
#  [400, 176888, 29011, 253263],
#  [500, 354810, 65432, 505803]]

# %%
import matplotlib.pyplot as plt

binary = [item[1] for item in data]
linear = [item[2] for item in data]
ternary = [item[3] for item in data]
time_values = [item[0] for item in data]

plt.figure()

plt.plot(time_values, binary, label="bellman", marker="o")
plt.plot(time_values, linear, label="dijkstra", marker="o")
plt.plot(time_values, ternary, label="floyd", marker="o")


plt.xlabel("Dataset size")
plt.ylabel("Time (s)")
plt.title("Shortest comparison")
plt.legend()
plt.grid(True)
plt.show()
